# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# df = pd.read_csv("../results/rssi_n10_10d_adr.csv")
# df = pd.read_csv("../results/rssi_n10_10d_noadr.csv")
df = pd.read_csv("../results/rssi_n10_10d_noadr_location_generated_bigwall_nakagami.csv")
df
# Out:
#      Vector of RSSI per node LoRaNetwork.networkServer.app[0] ($0="avg", #0 - General-0-20230429-20:46:24-82182)  \
# 0                                            60.106803
# 1                                            61.306803
# 2                                          1733.518003
# 3                                          2048.239664
# 4                                          3227.622595
# ..                                                 ...
# 538                                                NaN
# 539                                                NaN
# 540                                                NaN
# 541                                                NaN
# 542                                                NaN
#
#      Unnamed: 1  \
# 0    -93.722221
# 1    -93.722221
# 2    -97.642865
# 3    -92.636558
# 4   -105.809357
# ..          ...
# 538         NaN
# 539         NaN
# 540         NaN
# 541         NaN
# 542         NaN
#
#      Vector of RSSI per node LoRaNetwork.networkServer.app[0] ($0="avg", #0 - General-0-20230429-20:46:24-82182).1  \
# 0                                           320.078274
# 1                                           321.278274
# 2                                           780.526412
# 3                                          3973.473054
# 4                                          4543.370619
# ..                                                 ...
# 538                                                NaN
# 539                                                NaN
# 540                                                NaN
# 541                                                NaN
# 542                                                NaN
#
#      Unnamed: 3  \
# 0    -46.322937
# 1    -46.322937
# 2    -51.062133
# 3    -55.581397
# 4    -50.740820
# ..          ...
# 538         NaN
# 539         NaN
# 540         NaN
# 541         NaN
# 542         NaN
#
#      Vector of RSSI per node LoRaNetwork.networkServer.app[0] ($0="avg", #0 - General-0-20230429-20:46:24-82182).2  \
# 0                                           354.881270
# 1                                           356.081270
# 2                                          1091.045691
# 3                                          3196.366995
# 4                                          5080.295879
# ..                                                 ...
# 538                                                NaN
# 539                                                NaN
# 540                                                NaN
# 541                                                NaN
# 542                                                NaN
#
#      Unnamed: 5  \
# 0    -44.900436
# 1    -44.900436
# 2    -48.699480
# 3    -43.694352
# 4    -52.813793
# ..          ...
# 538         NaN
# 539         NaN
# 540         NaN
# 541         NaN
# 542         NaN
#
#      Vector of RSSI per node LoRaNetwork.networkServer.app[0] ($0="avg", #0 - General-0-20230429-20:46:24-82182).3  \
# 0                                           485.324239
# 1                                           486.524239
# 2                                          1022.089959
# 3                                          4009.279848
# 4                                          5371.211575
# ..                                                 ...
# 538                                                NaN
# 539                                                NaN
# 540                                                NaN
# 541                                                NaN
# 542                                                NaN
#
#      Unnamed: 7  \
# 0    -56.987831
# 1    -56.987831
# 2    -51.503803
# 3    -53.725830
# 4    -48.695591
# ..          ...
# 538         NaN
# 539         NaN
# 540         NaN
# 541         NaN
# 542         NaN
#
#      Vector of RSSI per node LoRaNetwork.networkServer.app[0] ($0="avg", #0 - General-0-20230429-20:46:24-82182).4  \
# 0                                           577.241328
# 1                                           578.441328
# 2                                          1527.935912
# 3                                          4177.191840
# 4                                          5215.041918
# ..                                                 ...
# 538                                                NaN
# 539                                                NaN
# 540                                                NaN
# 541                                                NaN
# 542                                                NaN
#
#      Unnamed: 9  \
# 0    -92.820958
# 1    -92.820958
# 2   -113.867036
# 3    -91.098993
# 4   -105.461993
# ..          ...
# 538         NaN
# 539         NaN
# 540         NaN
# 541         NaN
# 542         NaN
#
#      Vector of RSSI per node LoRaNetwork.networkServer.app[0] ($0="avg", #0 - General-0-20230429-20:46:24-82182).5  \
# 0                                           651.168482
# 1                                           652.368482
# 2                                          1095.772508
# 3                                          4987.342631
# 4                                          6110.803133
# ..                                                 ...
# 538                                                NaN
# 539                                                NaN
# 540                                                NaN
# 541                                                NaN
# 542                                                NaN
#
#      Unnamed: 11  \
# 0     -61.504468
# 1     -61.504468
# 2     -67.039752
# 3     -57.046884
# 4     -55.112043
# ..           ...
# 538          NaN
# 539          NaN
# 540          NaN
# 541          NaN
# 542          NaN
#
#      Vector of RSSI per node LoRaNetwork.networkServer.app[0] ($0="avg", #0 - General-0-20230429-20:46:24-82182).6  \
# 0                                           878.621106
# 1                                           879.821106
# 2                                          1523.602110
# 3                                          1767.997555
# 4                                          2617.218369
# ..                                                 ...
# 538                                                NaN
# 539                                                NaN
# 540                                                NaN
# 541                                                NaN
# 542                                                NaN
#
#      Unnamed: 13  \
# 0    -129.313145
# 1    -129.313145
# 2    -122.450067
# 3    -120.621152
# 4    -127.949908
# ..           ...
# 538          NaN
# 539          NaN
# 540          NaN
# 541          NaN
# 542          NaN
#
#      Vector of RSSI per node LoRaNetwork.networkServer.app[0] ($0="avg", #0 - General-0-20230429-20:46:24-82182).7  \
# 0                                          1570.618249
# 1                                          1571.818249
# 2                                          1774.168687
# 3                                          2127.188821
# 4                                          3059.591704
# ..                                                 ...
# 538                                      661764.272372
# 539                                      664096.006463
# 540                                      665758.924903
# 541                                      666254.067251
# 542                                      668189.507273
#
#      Unnamed: 15  \
# 0     -63.714267
# 1     -63.714267
# 2     -55.760460
# 3     -55.272666
# 4     -70.443024
# ..           ...
# 538   -58.317433
# 539   -54.307371
# 540   -61.116433
# 541   -55.102999
# 542   -64.070042
#
#      Vector of RSSI per node LoRaNetwork.networkServer.app[0] ($0="avg", #0 - General-0-20230429-20:46:24-82182).8  \
# 0                                          2225.246556
# 1                                          2226.446556
# 2                                          2786.407626
# 3                                          5011.322280
# 4                                          5240.566606
# ..                                                 ...
# 538                                                NaN
# 539                                                NaN
# 540                                                NaN
# 541                                                NaN
# 542                                                NaN
#
#      Unnamed: 17  \
# 0     -79.685224
# 1     -79.685224
# 2     -88.128970
# 3     -90.978321
# 4     -82.074562
# ..           ...
# 538          NaN
# 539          NaN
# 540          NaN
# 541          NaN
# 542          NaN
#
#      Vector of RSSI per node LoRaNetwork.networkServer.app[0] ($0="avg", #0 - General-0-20230429-20:46:24-82182).9  \
# 0                                          3316.634414
# 1                                          3317.834414
# 2                                          3764.087232
# 3                                          5294.918458
# 4                                          5707.648327
# ..                                                 ...
# 538                                                NaN
# 539                                                NaN
# 540                                                NaN
# 541                                                NaN
# 542                                                NaN
#
#      Unnamed: 19
# 0     -59.729933
# 1     -59.729933
# 2     -65.344851
# 3     -58.269243
# 4     -56.235568
# ..           ...
# 538          NaN
# 539          NaN
# 540          NaN
# 541          NaN
# 542          NaN
#
# [543 rows x 20 columns]

# %%
# rssi_n10_10d_noadr_location_generated.csv
locations = [[432.51, 481.56], [545.87, 435.16], [476.36, 518.18], [484.83, 468.03], [547.28, 418.85], [442.3, 494.69], [528.67, 541.73], [551.7, 515.53], [425.33, 580.96], [501.35, 589.68]]
distances = [69.96380278401111, 79.42469704065604, 29.82217295905846, 35.386576551003095, 93.9186930275331, 57.9438184796273, 50.62965336638203, 53.982135007796835, 110.1368716643069, 89.6901605528722]
initial_node_order = ['node0', 'node1', 'node2', 'node3', 'node4', 'node5', 'node6', 'node7', 'node8', 'node9']
conditions = pd.DataFrame(distances, index=initial_node_order)
conditions
# Out:
#                 0
# node0   69.963803
# node1   79.424697
# node2   29.822173
# node3   35.386577
# node4   93.918693
# node5   57.943818
# node6   50.629653
# node7   53.982135
# node8  110.136872
# node9   89.690161

# %%
df_count = pd.read_csv("../results/count_n10_10d_noadr_location_generated_bigwall_nakagami.csv")
df_count
# Out:
#                                  run  repetition  \
# 0  General-0-20230429-20:46:24-82182           0
# 1  General-0-20230429-20:46:24-82182           0
# 2  General-0-20230429-20:46:24-82182           0
# 3  General-0-20230429-20:46:24-82182           0
# 4  General-0-20230429-20:46:24-82182           0
# 5  General-0-20230429-20:46:24-82182           0
# 6  General-0-20230429-20:46:24-82182           0
# 7  General-0-20230429-20:46:24-82182           0
# 8  General-0-20230429-20:46:24-82182           0
# 9  General-0-20230429-20:46:24-82182           0
#
#                              module                   name  value
# 0  LoRaNetwork.networkServer.app[0]  numReceivedFromNode 0    442
# 1  LoRaNetwork.networkServer.app[0]  numReceivedFromNode 1    498
# 2  LoRaNetwork.networkServer.app[0]  numReceivedFromNode 2    508
# 3  LoRaNetwork.networkServer.app[0]  numReceivedFromNode 3    505
# 4  LoRaNetwork.networkServer.app[0]  numReceivedFromNode 4    511
# 5  LoRaNetwork.networkServer.app[0]  numReceivedFromNode 5    523
# 6  LoRaNetwork.networkServer.app[0]  numReceivedFromNode 6    527
# 7  LoRaNetwork.networkServer.app[0]  numReceivedFromNode 7    531
# 8  LoRaNetwork.networkServer.app[0]  numReceivedFromNode 8    537
# 9  LoRaNetwork.networkServer.app[0]  numReceivedFromNode 9    542

# %%
node_order = []
unamed_list = []
for i in range(len(df_count)):
    unamed_list.append("Unnamed: "+str(i*2+1))
for i in unamed_list:
    node_num = df_count.loc[df_count["value"] == df[i].count()-1].index[0]
    node_order.append("node"+str(node_num))
print(node_order)
# Out:
# ['node4', 'node6', 'node2', 'node7', 'node1', 'node8', 'node0', 'node9', 'node3', 'node5']

# %%
rssi_values = df[unamed_list]
rssi_values.set_axis(node_order, axis='columns', inplace=True)
print(rssi_values.head())
# Out:
#         node4      node6      node2      node7       node1      node8  \
# 0  -93.722221 -46.322937 -44.900436 -56.987831  -92.820958 -61.504468
# 1  -93.722221 -46.322937 -44.900436 -56.987831  -92.820958 -61.504468
# 2  -97.642865 -51.062133 -48.699480 -51.503803 -113.867036 -67.039752
# 3  -92.636558 -55.581397 -43.694352 -53.725830  -91.098993 -57.046884
# 4 -105.809357 -50.740820 -52.813793 -48.695591 -105.461993 -55.112043
#
#         node0      node9      node3      node5
# 0 -129.313145 -63.714267 -79.685224 -59.729933
# 1 -129.313145 -63.714267 -79.685224 -59.729933
# 2 -122.450067 -55.760460 -88.128970 -65.344851
# 3 -120.621152 -55.272666 -90.978321 -58.269243
# 4 -127.949908 -70.443024 -82.074562 -56.235568

# %%
# rssi_values.plot.line()
plt.figure(facecolor="white")
plt.plot(rssi_values)
plt.legend(rssi_values)
plt.ylabel("RSSI(dBm)")
plt.show()

# %%
rssi_values.plot.hist(bins=20, alpha=0.8)
# plt.figure(facecolor="white")
# plt.hist(rssi_values, bins=20)
# plt.show()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.figure(facecolor="white")
plt.plot(rssi_values["node8"])
plt.show()

# %%
rssi_values["node8"].plot.hist(bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
def plot_qq_statsmodels_horizontal(data, distribution_type):
    fig, ax = plt.subplots(1, len(data.columns), figsize=(5 * len(data.columns), 5), sharey=True)
    for idx, column in enumerate(data.columns):
        if distribution_type == "normal":
            sm.qqplot(data[column], line="r", ax=ax[idx])
        elif distribution_type == "lognormal":
            sm.qqplot(np.log(data[column] - data[column].min() + 1), line="r", ax=ax[idx])
        ax[idx].set_title(f"{column} - {distribution_type.capitalize()}")

    plt.tight_layout()
    plt.suptitle(f"QQ plots for {distribution_type.capitalize()} Distribution", fontsize=16, y=1.05)
    plt.show()


cleaned_rssi_values = rssi_values.dropna()
scaler = StandardScaler()
normalized_rssi_values = pd.DataFrame(scaler.fit_transform(cleaned_rssi_values), columns=cleaned_rssi_values.columns)


plot_qq_statsmodels_horizontal(normalized_rssi_values, "normal")
plot_qq_statsmodels_horizontal(normalized_rssi_values, "lognormal")

# %% [markdown]
# - norm dist because there is no multipath
# - the reason left end is above the line is that we cannot detect signal below -130dBm

# %%
# Set up the figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Create histograms or KDE plots for each node
for column in rssi_values.columns:
    sns.histplot(rssi_values[column], kde=True, ax=ax, label=column)

# Customize the plot
ax.set_title("Distribution of Nodes")
ax.set_xlabel("Value")
ax.set_ylabel("Frequency")
ax.legend()

# Display the plot
plt.show()

# %%
# Calculate the cumulative sum for each column
cumulative_sum = rssi_values.cumsum()

# Calculate the cumulative count for each column
cumulative_count = rssi_values.apply(lambda x: (x.notna().cumsum()))

# Compute the average value for each element by dividing cumulative sum by cumulative count
average_df = cumulative_sum / cumulative_count

# Display the new DataFrame with the average values
plt.figure(facecolor="white")
plt.plot(average_df)
plt.legend(average_df)
plt.ylabel("RSSI (dBm)")
plt.show()
# average_df.plot.line()

# %%
mean_rssi = pd.DataFrame(rssi_values.mean())
rssi_distance = pd.merge(conditions, mean_rssi, left_index=True, right_index=True)
rssi_distance.columns = ["distance", "rssi"]
print(rssi_distance)
rssi_distance.plot.scatter(x="distance",y="rssi")
# Out:
#          distance        rssi
# node0   69.963803 -127.029527
# node1   79.424697  -95.724856
# node2   29.822173  -49.181774
# node3   35.386577  -84.970617
# node4   93.918693  -95.621641
# node5   57.943818  -54.251893
# node6   50.629653  -54.246247
# node7   53.982135  -54.522521
# node8  110.136872  -60.743041
# node9   89.690161  -58.834929
# <AxesSubplot:xlabel='distance', ylabel='rssi'>

# %%
# Create a mapping from node names to their corresponding distance
node_to_distance = conditions.squeeze().to_dict()
print(node_to_distance)

# Create an empty array to store x (distance) and y (rssi) values for the scatter plot
x_values = []
y_values = []

# Iterate through the columns (nodes) in rssi_values
for node in rssi_values.columns:
    # Get the distance for the current node
    print(node)
    distance = node_to_distance[node]
    
    # Get the rssi values for the current node
    rssi_values_node = rssi_values[node].dropna()
    
    # Append the distance value to x_values as many times as there are rssi values
    x_values.extend([distance] * len(rssi_values_node))
    
    # Append the rssi values to y_values
    y_values.extend(rssi_values_node)

# Create the scatter plot
plt.figure(figsize=(10, 6), facecolor="white")
plt.scatter(x_values, y_values, alpha=0.6)

# Add labels and title
plt.xlabel("Distance")
plt.ylabel("RSSI")
plt.title("Scatter Plot of RSSI vs Distance")

# Optionally, you can add a grid for better readability
plt.grid(True)

# Finally, display the plot
plt.show()
# Out:
# {'node0': 69.96380278401111, 'node1': 79.42469704065604, 'node2': 29.82217295905846, 'node3': 35.386576551003095, 'node4': 93.9186930275331, 'node5': 57.9438184796273, 'node6': 50.62965336638203, 'node7': 53.982135007796835, 'node8': 110.1368716643069, 'node9': 89.6901605528722}
# node4
# node6
# node2
# node7
# node1
# node8
# node0
# node9
# node3
# node5

# %%
# Create a list of node names
node_names = rssi_values.columns

# Create a mapping from node names to their corresponding distance
node_to_distance = conditions.squeeze().to_dict()

# Create a list of distances corresponding to the node names
distances_list = [node_to_distance[node] for node in node_names]

# Initialize an empty list to store the data for box plots
box_plot_data = []

# Add the RSSI values for each node to the box_plot_data list
for node in node_names:
    box_plot_data.append(rssi_values[node].dropna().tolist())

# Create custom ticks and labels for the x-axis
xticks = distances_list
xticklabels = [int(round(dist)) for dist in xticks]

# Calculate the mean RSSI for each node
mean_rssi_values = [np.mean(rssi) for rssi in box_plot_data]

# Sort the data by distances
sorted_data = sorted(zip(distances_list, box_plot_data, mean_rssi_values))
sorted_distances, sorted_box_plot_data, sorted_mean_rssi_values = zip(*sorted_data)

# Create a box plot for each node with distance on the x-axis
plt.figure(figsize=(12, 6), facecolor="white")
plt.boxplot(sorted_box_plot_data, positions=sorted_distances, widths=2)

# Set custom ticks and labels for the x-axis
sorted_xticks = sorted(xticks)
sorted_xticklabels = [str(int(round(d))) for d in sorted_xticks]
plt.xticks(sorted_xticks, sorted_xticklabels)

# Add labels and title
plt.xlabel("Distance (m)")
plt.ylabel("RSSI (dBm)")
plt.title("Boxplot of RSSI for Each Distance with Mean Line")

# Optionally, you can add a grid for better readability
plt.grid(axis='y')

# Plot a line connecting the mean RSSI values for each node
plt.plot(sorted_distances, sorted_mean_rssi_values, marker='o', linestyle='-', color='red', label='Mean RSSI')

# Add a legend to the plot
plt.legend()

# Finally, display the plot
plt.show()

# %% [markdown]
# # prediction
